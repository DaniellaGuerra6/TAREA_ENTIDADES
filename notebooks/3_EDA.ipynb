# %% [markdown]
# # Exploración de los datos

# %%
import pandas as pd

df = pd.read_excel("../data/2_categorized/SECOP_CAT_final.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3570 entries, 0 to 3569
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   nombre_entidad          3570 non-null   object
#  1   nit_entidad             3570 non-null   int64
#  2   codigo_entidad          3570 non-null   int64
#  3   sector                  3570 non-null   object
#  4   id_contrato             3570 non-null   object
#  5   estado_contrato         3570 non-null   object
#  6   modalidad_contrato      3570 non-null   object
#  7   anio                    3570 non-null   int64
#  8   codigo_categoria        3570 non-null   object
#  9   fecha_de_firma          3570 non-null   datetime64[ns]
#  10  tipodocproveedor        3570 non-null   object
#  11  documento_proveedor     3568 non-null   object
#  12  codigo_proveedor        3570 non-null   int64
#  13  proveedor_adjudicado    3570 non-null   object
#  14  origen_de_los_recursos  3570 non-null   object
#  15  destino_gasto           3570 non-null   object
#  16  valor_del_contrato      3570 non-null   int64
#  17  codigo_BPIN             3570 non-null   object
#  18  urlproceso              3570 non-null   object
#  19  recursos_PGN            3570 non-null   int64
#  20  recursos_SGP            3570 non-null   int64
#  21  recursos_SGR            3570 non-null   int64
#  22  recursos_territorio     3570 non-null   int64
#  23  recursos_credito        3570 non-null   int64
#  24  recursos_propios        3570 non-null   int64
#  25  codigo_familia_UNSPSC   3570 non-null   int64
#  26  nombre_familia_UNSPSC   3570 non-null   object
#  27  texto                   3570 non-null   object
#  28  objetos                 3570 non-null   object
#  29  objeto_contractual      3570 non-null   object
#  30  sub_categorias          3570 non-null   object
#  31  SUB                     3570 non-null   object
#  32  MACRO                   3570 non-null   object
# dtypes: datetime64[ns](1), int64(12), object(20)
# memory usage: 920.5+ KB

# %%
# Descripcion del dataset
print("Descripción del dataset:")
print(f" - Número de filas: {df.shape[0]}")
print(f" - Número de columnas: {df.shape[1]}")
print(f" - Columnas: {df.columns.tolist()}")
# Out:
# Descripción del dataset:
#  - Número de filas: 3570
#  - Número de columnas: 33
#  - Columnas: ['nombre_entidad', 'nit_entidad', 'codigo_entidad', 'sector', 'id_contrato', 'estado_contrato', 'modalidad_contrato', 'anio', 'codigo_categoria', 'fecha_de_firma', 'tipodocproveedor', 'documento_proveedor', 'codigo_proveedor', 'proveedor_adjudicado', 'origen_de_los_recursos', 'destino_gasto', 'valor_del_contrato', 'codigo_BPIN', 'urlproceso', 'recursos_PGN', 'recursos_SGP', 'recursos_SGR', 'recursos_territorio', 'recursos_credito', 'recursos_propios', 'codigo_familia_UNSPSC', 'nombre_familia_UNSPSC', 'texto', 'objetos', 'objeto_contractual', 'sub_categorias', 'SUB', 'MACRO']

# %%
df['nombre_entidad'] = df['nombre_entidad'].str.replace(r'[°*+]', ' ', regex=True).str.upper()

# %%
# TOP ENTIDADES CONTRATANTES
top_entidades = (
    df
    .groupby('nombre_entidad', as_index=False)
    .agg(
        valor_total=('valor_del_contrato', 'sum'),
        contratos=('id_contrato', 'count')
    )
    .sort_values('valor_total', ascending=False)
    .head(30)   # ajusta Top N aquí
)
print("Top 30 Entidades Contratantes por Valor Total de Contratos:")
display(top_entidades)
# Out:
# Top 30 Entidades Contratantes por Valor Total de Contratos:
#                                         nombre_entidad     valor_total  \
# 161                                             INVIAS  17858897949448
# 0                                            AEROCIVIL   1397161857481
# 64                                                 CVC    418390436721
# 61   CORPORACIÓN AUTÓNOMA DEL RÍO GRANDE DE LA MAGD...    356412469246
# 108                     FUERZA AEROESPACIAL COLOMBIANA    125052680222
# 36   CENTRAL ADMINISTRATIVA ESPECIALIZADA INGENIERO...     92488391718
# 81                                    ENTERRITORIO S.A     87042508678
# 153            INSTITUTO DE CASAS FISCALES DE EJERCITO     55288501937
# 106             FONDO ROTATORIO DE LA POLICIA NACIONAL     49616268391
# 60                               CORPORACION NASA KIWE     41980999987
# 70                                               DIEPO     28940841304
# 72       DIRECCION DE BIENESTAR DE LA POLICIA NACIONAL     27519616702
# 15                                      APC  COLOMBIA      24139080805
# 78                                   EDUNA (COMPRADOR)     21309787288
# 22   ARMADA NACIONAL ESCUELA NAVAL DE CADETES ALMIR...     20705872038
# 169                             MUNICIPIO DE ENVIGADO      18258687101
# 23   ARMADA NACIONAL ESCUELA NAVAL DE SUBOFICIALES ...     18136572934
# 82                  ESAP SEDE CENTRAL (CUENTA OFICIAL)     16752030035
# 17                                         ARC-BACAIM6     14042293596
# 79                                               EMAVI     11321195526
# 11                      ALCALDÍA MUNICIPAL DE MAGANGUE     10301175875
# 26                                       BASPC Nº 19        9377299417
# 77                                               ECSAN      8856819822
# 184                                 PROSPERIDAD SOCIAL      8502294000
# 95   ESCUELA INTERNACIONAL DE ENTRENAMIENTO DE LA P...      8144001670
# 183                  PROCURADURIA GENERAL DE LA NACION      7971214476
# 164  MINISTERIO DE LAS CULTURAS, LAS ARTES Y LOS SA...      7963915483
# 56         CORPORACION AUTONOMA REGIONAL DE SANTANDER       7845972315
# 166                             MINISTERIO DEL DEPORTE      7762500000
# 92                    ESCUELA DE POSTGRADOS DE POLICÍA      7720613239
#
#      contratos
# 161       2017
# 0          543
# 64          17
# 61           7
# 108         34
# 36          23
# 81          19
# 153         14
# 106          5
# 60          28
# 70           6
# 72           6
# 15           6
# 78          34
# 22          15
# 169          6
# 23          20
# 82           7
# 17           4
# 79          18
# 11          18
# 26           6
# 77           4
# 184          2
# 95           2
# 183          1
# 164          3
# 56           6
# 166         46
# 92           9

# %%
entidad_macro = (
    df
    .groupby(
        ['nombre_entidad', 'MACRO'],
        as_index=False
    )
    .agg(
        valor_total=('valor_del_contrato', 'sum'),
        contratos=('id_contrato', 'count')
    )
    .sort_values('valor_total', ascending=False)
)

# Top 10 entidades por MACRO
entidad_macro_top = (
    entidad_macro
    .groupby('MACRO', group_keys=False)
    .head(10)
)
print("Top 10 Entidades Contratantes por MACRO Categoria:")
display(entidad_macro_top)
# Out:
# Top 10 Entidades Contratantes por MACRO Categoria:
#                                         nombre_entidad  \
# 232                                             INVIAS
# 2                                            AEROCIVIL
# 231                                             INVIAS
# 102  CORPORACIÓN AUTÓNOMA DEL RÍO GRANDE DE LA MAGD...
# 107                                                CVC
# 171                     FUERZA AEROESPACIAL COLOMBIANA
# 68   CENTRAL ADMINISTRATIVA ESPECIALIZADA INGENIERO...
# 106                                                CVC
# 135                                   ENTERRITORIO S.A
# 221            INSTITUTO DE CASAS FISCALES DE EJERCITO
# 165             FONDO ROTATORIO DE LA POLICIA NACIONAL
# 101                              CORPORACION NASA KIWE
# 170                     FUERZA AEROESPACIAL COLOMBIANA
# 29                                      APC  COLOMBIA
# 115                                              DIEPO
# 42   ARMADA NACIONAL ESCUELA NAVAL DE CADETES ALMIR...
# 119      DIRECCION DE BIENESTAR DE LA POLICIA NACIONAL
# 43   ARMADA NACIONAL ESCUELA NAVAL DE SUBOFICIALES ...
# 133                                   ENTERRITORIO S.A
# 242                             MUNICIPIO DE ENVIGADO
# 66   CENTRAL ADMINISTRATIVA ESPECIALIZADA INGENIERO...
# 31                                         ARC-BACAIM6
# 118      DIRECCION DE BIENESTAR DE LA POLICIA NACIONAL
# 134                                   ENTERRITORIO S.A
# 261                  PROCURADURIA GENERAL DE LA NACION
# 21                      ALCALDÍA MUNICIPAL DE MAGANGUE
# 114                                              DIEPO
# 244                             MUNICIPIO DE MARINILLA
# 128                                  EDUNA (COMPRADOR)
# 100                              CORPORACION NASA KIWE
# 93         CORPORACION AUTONOMA REGIONAL DE SANTANDER
# 91                                         CORMACARENA
# 240                             MUNICIPIO DE ENVIGADO
# 149  ESCUELA DE SUBOFICIALES Y NIVEL EJECUTIVO  GON...
# 105                                          CORTOLIMA
# 330  SUBCUENTA DEL SISTEMA DE PARQUES NACIONALES NA...
# 104      CORPORACIÓN AUTÓNOMA REGIONAL DE LA ORINOQUIA
# 20                      ALCALDÍA MUNICIPAL DE MAGANGUE
# 253  PARQUES NACIONALES NATURALES DE COLOMBIA - DIR...
# 331  SUBCUENTA DEL SISTEMA DE PARQUES NACIONALES NA...
#
#                                     MACRO     valor_total  contratos
# 232                            Transporte  17367048309138       1994
# 2                              Transporte   1394999613041        525
# 231    Ambiental y gestion del territorio    491849640310         23
# 102    Ambiental y gestion del territorio    356363059435          6
# 107             Productiva y de servicios    343917667842          8
# 171  Urbanismo y desarrollo metropolitano     87200034403         23
# 68   Urbanismo y desarrollo metropolitano     77787629919         15
# 106    Ambiental y gestion del territorio     67907017390          6
# 135  Urbanismo y desarrollo metropolitano     63289617090          5
# 221  Urbanismo y desarrollo metropolitano     54987485028         12
# 165  Urbanismo y desarrollo metropolitano     49489783648          4
# 101  Urbanismo y desarrollo metropolitano     35839607125         21
# 170                            Transporte     34328736021         10
# 29                             Transporte     24139080805          6
# 115  Urbanismo y desarrollo metropolitano     21556067213          5
# 42   Urbanismo y desarrollo metropolitano     20705872038         15
# 119  Urbanismo y desarrollo metropolitano     19093902024          2
# 43   Urbanismo y desarrollo metropolitano     18136572934         20
# 133             Productiva y de servicios     15724953886          6
# 242                            Transporte     14449257659          3
# 66              Productiva y de servicios     12860119706          5
# 31              Productiva y de servicios      9359341423          2
# 118                            Transporte      8225753054          2
# 134                            Transporte      8027937702          8
# 261                            Transporte      7971214476          1
# 21              Productiva y de servicios      7873607666          4
# 114                            Transporte      7384774091          1
# 244                            Transporte      7069041457          4
# 128             Productiva y de servicios      6277101110          5
# 100             Productiva y de servicios      6141392862          7
# 93              Productiva y de servicios      4772291132          2
# 91              Productiva y de servicios      4091799463          1
# 240    Ambiental y gestion del territorio      3748898383          1
# 149             Productiva y de servicios      3717500000          1
# 105    Ambiental y gestion del territorio      2091829430          3
# 330    Ambiental y gestion del territorio      1629297206          3
# 104    Ambiental y gestion del territorio      1586097977          2
# 20     Ambiental y gestion del territorio      1563891880          2
# 253    Ambiental y gestion del territorio      1173597483         11
# 331    Ambiental y gestion del territorio      1107672526          3

# %%
entidad_macro_sub = (
    df
    .groupby(
        ['nombre_entidad', 'MACRO', 'SUB'],
        as_index=False
    )
    .agg(
        valor_total=('valor_del_contrato', 'sum'),
        contratos=('id_contrato', 'count')
    )
    .sort_values('valor_total', ascending=False)
)

# Top 10 por MACRO + SUB
entidad_macro_sub_top = (
    entidad_macro_sub
    .groupby(
        ['MACRO', 'SUB'],
        group_keys=False
    )
    .head(10)
)

print("Top 10 Entidades Contratantes por MACRO y SUB Categoria:")
display(entidad_macro_sub_top)
# Out:
# Top 10 Entidades Contratantes por MACRO y SUB Categoria:
#                                nombre_entidad  \
# 281                                    INVIAS
# 280                                    INVIAS
# 279                                    INVIAS
# 3                                   AEROCIVIL
# 282                                    INVIAS
# ..                                        ...
# 382                       SENA REGIONAL SUCRE
# 33             ALCALDÍA MUNICIPAL DE MAGANGUE
# 333                    SENA REGIONAL AMAZONAS
# 258   INSTITUTO COLOMBIANO AGROPECUARIO - ICA
# 399  SUPERINTENDENCIA DE NOTARIADO Y REGISTRO
#
#                                     MACRO              SUB     valor_total  \
# 281                            Transporte             Vias  13135388584647
# 280                            Transporte           Puerto   1779516883475
# 279                            Transporte           Puente   1639717957593
# 3                              Transporte       Aeropuerto   1365398387469
# 282                            Transporte  Vias terciarias    781437742421
# ..                                    ...              ...             ...
# 382             Productiva y de servicios          Turismo        50192827
# 33   Urbanismo y desarrollo metropolitano     Vias urbanas        36710795
# 333             Productiva y de servicios          Turismo        20482500
# 258                            Transporte       Aeropuerto        18047699
# 399  Urbanismo y desarrollo metropolitano     Vias urbanas        10059544
#
#      contratos
# 281       1595
# 280         42
# 279         57
# 3          474
# 282        298
# ..         ...
# 382          1
# 33           1
# 333          1
# 258          1
# 399          1
#
# [138 rows x 5 columns]

# %%
entidad_objeto = (
    df
    .groupby(
        ['nombre_entidad', 'objeto_contractual'],
        as_index=False
    )
    .agg(
        valor_total=('valor_del_contrato', 'sum'),
        contratos=('id_contrato', 'count')
    )
    .sort_values('valor_total', ascending=False)
)

# Top 20 objetos por entidad
entidad_objeto_top = (
    entidad_objeto
    .groupby('nombre_entidad', group_keys=False)
    .head(20)
)
print("Top 20 Objetos Contractuales por Entidad Contratante:")
display(entidad_objeto_top)
# Out:
# Top 20 Objetos Contractuales por Entidad Contratante:
#                                         nombre_entidad objeto_contractual  \
# 266                                             INVIAS       Mejoramiento
# 264                                             INVIAS       Construccion
# 265                                             INVIAS      Mantenimiento
# 2                                            AEROCIVIL       Construccion
# 4                                            AEROCIVIL       Mejoramiento
# ..                                                 ...                ...
# 133  DIRECCION GENERAL MARITIMA - SUBDIRECCION ADMI...       Construccion
# 206                              ICBF REGIONAL VICHADA       Construccion
# 313  RAMA JUDICIAL  DIRECCIÓN SECCIONAL DE ADMINIS...              Otros
# 217  INSTITUCION EDUCATIVA DISTRITAL ANTONIO JOSE D...         Reparacion
# 247  INSTITUTO COLOMBIANO AGROPECUARIO-SECCIONAL CA...      Mantenimiento
#
#         valor_total  contratos
# 266  10370312851429        476
# 264   3758155297706        108
# 265   2955104000785       1092
# 2      466864008352         55
# 4      432361390072         42
# ..              ...        ...
# 133         7305069          1
# 206         6428335          1
# 313         5953007          1
# 217         3500000          1
# 247         1350000          1
#
# [400 rows x 4 columns]

# %%
macro_objeto_entidad = (
    df
    .groupby(
        ['MACRO', 'objeto_contractual', 'nombre_entidad'],
        as_index=False
    )
    .agg(
        valor_total=('valor_del_contrato', 'sum'),
        contratos=('id_contrato', 'count')
    )
    .sort_values('valor_total', ascending=False)
)

# Top 10 entidades por MACRO + objeto
macro_objeto_entidad_top = (
    macro_objeto_entidad
    .groupby(
        ['MACRO', 'objeto_contractual'],
        group_keys=False
    )
    .head(10)
)

print("Top 10 Entidades Contratantes por MACRO Categoria y Objeto Contractual:")
display(macro_objeto_entidad_top)
# Out:
# Top 10 Entidades Contratantes por MACRO Categoria y Objeto Contractual:
#                                     MACRO objeto_contractual  \
# 282                            Transporte       Mejoramiento
# 234                            Transporte       Construccion
# 267                            Transporte      Mantenimiento
# 220                            Transporte       Construccion
# 271                            Transporte       Mejoramiento
# ..                                    ...                ...
# 179             Productiva y de servicios       Mejoramiento
# 6      Ambiental y gestion del territorio         Adecuacion
# 302                            Transporte         Reparacion
# 46     Ambiental y gestion del territorio              Otros
# 491  Urbanismo y desarrollo metropolitano         Reparacion
#
#                                         nombre_entidad     valor_total  \
# 282                                             INVIAS  10060713460031
# 234                                             INVIAS   3750791827491
# 267                                             INVIAS   2839760513420
# 220                                          AEROCIVIL    466201274768
# 271                                          AEROCIVIL    431811679496
# ..                                                 ...             ...
# 179                 SENA HOTELERIA TURISMO Y ALIMENTOS        28638836
# 6    SUBCUENTA DEL SISTEMA DE PARQUES NACIONALES NA...        24485305
# 302  INSTITUTO NACIONAL DE MEDICINA LEGAL Y CIENCIA...        16621182
# 46   SENA REGIONAL GUAINÍA GRUPO DE APOYO ADMINISTR...        10659700
# 491  INSTITUCION EDUCATIVA DISTRITAL ANTONIO JOSE D...         3500000
#
#      contratos
# 282        473
# 234        106
# 267       1078
# 220         52
# 271         36
# ..         ...
# 179          1
# 6            1
# 302          1
# 46           1
# 491          1
#
# [208 rows x 5 columns]

# %%
ruta_salida = "tablas_resultado_contratacion.xlsx"

    top_entidades.to_excel(writer, sheet_name="Top_Entidades", index=False)
    entidad_macro_top.to_excel(writer, sheet_name="Entidad_x_MACRO", index=False)
    entidad_macro_sub_top.to_excel(writer, sheet_name="Entidad_x_MACRO_x_SUB", index=False)
    entidad_objeto_top.to_excel(writer, sheet_name="Entidad_x_Objeto", index=False)
    macro_objeto_entidad_top.to_excel(writer, sheet_name="MACRO_x_Objeto_x_Entidad", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 3
#       1 ruta_salida = "tablas_resultado_contratacion.xlsx"
# ----> 3 with pd.ExcelWriter(ruta_salida, engine="xlsxwriter") as writer:
#       4     top_entidades.to_excel(writer, sheet_name="Top_Entidades", index=False)
#       5     entidad_macro_top.to_excel(writer, sheet_name="Entidad_x_MACRO", index=False)
#
# File c:\Users\usuario\miniconda3\envs\POTENCIA\Lib\site-packages\pandas\io\excel\_xlsxwriter.py:197, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     184 def __init__(
#     185     self,
#     186     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)    195 ) -> None:
#     196     # Use the xlsxwriter module as the Excel writer.
# --> 197     from xlsxwriter import Workbook
#     199     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#     201     if mode == "a":
#
# ModuleNotFoundError: No module named 'xlsxwriter'
