# %% [markdown]
# # Exploración de los datos

# %%
# IMPORTS
# -------------------------
import pandas as pd
import os

# %%
# RUTAS
# -------------------------
BASE_PATH = r"C:\Users\usuario\OneDrive - POTENCIA\PROYECTOS\TAREA_ENTIDADES"
DATAPATH = os.path.join(BASE_PATH, "data", "ARCHIVOS")
os.makedirs(DATAPATH, exist_ok=True)
df = pd.read_excel(os.path.join(DATAPATH, "SECOP_CATEGORIZED.xlsx"))

print(f"📍 DataFrame Inicial:\n Dimensiones: {df.shape}")
# Out:
# 📍 DataFrame Inicial:
#  Dimensiones: (2818, 31)

# %%
# Descripcion del dataset
print("Descripción del dataset:")
print(f" - Número de filas: {df.shape[0]}")
print(f" - Número de columnas: {df.shape[1]}")
print(f" - Columnas: {df.columns}")
# Out:
# Descripción del dataset:
#  - Número de filas: 2818
#  - Número de columnas: 31
#  - Columnas: Index(['nombre_entidad', 'nit_entidad', 'codigo_entidad', 'sector',
#        'id_contrato', 'estado_contrato', 'modalidad_contrato',
#        'codigo_categoria', 'fecha_de_firma', 'tipodocproveedor',
#        'documento_proveedor', 'codigo_proveedor', 'proveedor_adjudicado',
#        'origen_de_los_recursos', 'destino_gasto', 'valor_del_contrato',
#        'codigo_BPIN', 'urlproceso', 'recursos_PGN', 'recursos_SGP',
#        'recursos_SGR', 'recursos_territorio', 'recursos_credito',
#        'recursos_propios', 'anio', 'texto', 'objetos', 'objeto_contractual',
#        'subcategorias', 'SUB', 'MACRO'],
#       dtype='object')

# %% [markdown]
# _________________________

# %% [markdown]
# ## TOP DE ENTIDADES

# %%
# TABLA: Por valor de contrato
entidades = (
    df
    .groupby('nombre_entidad', as_index=False)
    .agg(
        valor_total=('valor_del_contrato', 'sum'),  # Agrupación por valor
        contratos=('id_contrato', 'count') 
    )
    .sort_values('valor_total', ascending=False)
    .head(30) 
)


# TABLA: MACRO categorias por valor del contrato
entidad_macro = (
    df
    .groupby(
        ['nombre_entidad', 'MACRO'],
        as_index=False
    )
    .agg(
        valor_total=('valor_del_contrato', 'sum'),
        contratos=('id_contrato', 'count')
    )
    .sort_values('valor_total', ascending=False)
)

# TABLA: SUB categorias por valor del contrato
entidad_macro_sub = (
    df
    .groupby(
        ['nombre_entidad', 'MACRO', 'SUB'],
        as_index=False
    )
    .agg(
        valor_total=('valor_del_contrato', 'sum'),
        contratos=('id_contrato', 'count')
    )
    .sort_values('valor_total', ascending=False)
)

# TABLA: Objeto contractual por valor de contrato
entidad_objeto = (
    df
    .groupby(
        ['nombre_entidad', 'objeto_contractual'],
        as_index=False
    )
    .agg(
        valor_total=('valor_del_contrato', 'sum'),
        contratos=('id_contrato', 'count')
    )
    .sort_values('valor_total', ascending=False)
)

# TABLA: MACRO x Objeto contractual por 
macro_objeto_entidad = (
    df
    .groupby(
        ['MACRO', 'objeto_contractual', 'nombre_entidad'],
        as_index=False
    )
    .agg(
        valor_total=('valor_del_contrato', 'sum'),
        contratos=('id_contrato', 'count')
    )
    .sort_values('valor_total', ascending=False)
)

# %% [markdown]
# ___________

# %%
print("Top 30 Entidades Contratantes por Valor Total de Contratos:")
display(entidades)
# Out:
# Top 30 Entidades Contratantes por Valor Total de Contratos:
#                                         nombre_entidad     valor_total  \
# 84                                              INVIAS  15595552846907
# 0                                            AEROCIVIL   1062730954420
# 34   CORPORACIÓN AUTÓNOMA DEL RÍO GRANDE DE LA MAGD...    352687798312
# 15                                                 ANI    147226582104
# 36                                                 CVC    101016703194
# 41   EMPRESA NACIONAL PROMOTORA DEL DESARROLLO TERR...     85281878489
# 16                                       APC  COLOMBIA     24139080805
# 33                               CORPORACION NASA KIWE     20626612749
# 39                                   EDUNA (COMPRADOR)     19779662223
# 91                              MUNICIPIO DE MARINILLA     17152845094
# 42                  ESAP SEDE CENTRAL (CUENTA OFICIAL)     16752030035
# 11                      ALCALDÍA MUNICIPAL DE MAGANGUE     15134384807
# 35                                           CORTOLIMA     14832929676
# 57                                             IDARTES      9710125195
# 7                         ALCALDIA MUNICIPAL SARDINATA      9426104357
# 52                                               ICANH      8466668602
# 100                  PROCURADURIA GENERAL DE LA NACION      7971214476
# 48      FISCALÍA GENERAL DE LA NACIÓN REGIONAL CENTRAL      7503194961
# 2                              AGUAS LA CRISTALINA ESP      7238071757
# 87                              MINISTERIO DEL DEPORTE      7087500000
# 12                    ALCALDÍA MUNICIPAL DE ROLDANILLO      5837189918
# 102  SECRETARIA DISTRITAL DE SEGURIDAD, CONVIVENCIA...      5286131383
# 90                               MUNICIPIO DE ENVIGADO      4851151527
# 86   MINISTERIO DE LAS CULTURAS, LAS ARTES Y LOS SA...      4540242032
# 22                        COMANDO AÉREO DE COMBATE NO.      4188564545
# 27                                         CORMACARENA      4091799463
# 45   ESCUELA INTERNACIONAL DE ENTRENAMIENTO DE LA P...      3200830000
# 40   EMPRESA DE DESARROLLO URBANO Y RURAL DE ANTIOQUIA      2834839405
# 46       ESCUELA TECNOLÓGICA INSTITUTO TÉCNICO CENTRAL      2782928367
# 109               SENA REGIONAL ATLANTICO INTERCENTROS      2781358864
#
#      contratos
# 84        1861
# 0          322
# 34           6
# 15           1
# 36           6
# 41          11
# 16           6
# 33          59
# 39          28
# 91           8
# 42           7
# 11         110
# 35           2
# 57           1
# 7           16
# 52           2
# 100          1
# 48           7
# 2            3
# 87          42
# 12          25
# 102          1
# 90           3
# 86           2
# 22           9
# 27           1
# 45           1
# 40           1
# 46           4
# 109          1

# %%
# Top 10 entidades por MACRO
entidad_macro_top = (
    entidad_macro
    .groupby('MACRO', group_keys=False)
    .head(10)
)
entidad_macro_top.columns = [
    "Entidad",
    "Categoría MACRO",
    "Valor Total",
    "Número de contratos"
]
print("Top 10 Entidades Contratantes por MACRO Categoria:")
display(entidad_macro_top)
# Out:
# Top 10 Entidades Contratantes por MACRO Categoria:
#                                                Entidad  \
# 117                                             INVIAS
# 2                                            AEROCIVIL
# 52   CORPORACIÓN AUTÓNOMA DEL RÍO GRANDE DE LA MAGD...
# 118                                             INVIAS
# 116                                             INVIAS
# 25                                                 ANI
# 56                                                 CVC
# 68   EMPRESA NACIONAL PROMOTORA DEL DESARROLLO TERR...
# 26                                       APC  COLOMBIA
# 69                  ESAP SEDE CENTRAL (CUENTA OFICIAL)
# 54                                           CORTOLIMA
# 64                                   EDUNA (COMPRADOR)
# 55                                                 CVC
# 50                               CORPORACION NASA KIWE
# 87                                             IDARTES
# 10                        ALCALDIA MUNICIPAL SARDINATA
# 66   EMPRESA NACIONAL PROMOTORA DEL DESARROLLO TERR...
# 82                                               ICANH
# 140                  PROCURADURIA GENERAL DE LA NACION
# 17                      ALCALDÍA MUNICIPAL DE MAGANGUE
# 77      FISCALÍA GENERAL DE LA NACIÓN REGIONAL CENTRAL
# 5                              AGUAS LA CRISTALINA ESP
# 121                             MINISTERIO DEL DEPORTE
# 129                             MUNICIPIO DE MARINILLA
# 51                               CORPORACION NASA KIWE
# 63                                   EDUNA (COMPRADOR)
# 130                             MUNICIPIO DE MARINILLA
# 57                                                 CVC
# 120  MINISTERIO DE LAS CULTURAS, LAS ARTES Y LOS SA...
# 128                             MUNICIPIO DE MARINILLA
# 39                                         CORMACARENA
# 125                              MUNICIPIO DE ENVIGADO
# 49                               CORPORACION NASA KIWE
# 65   EMPRESA DE DESARROLLO URBANO Y RURAL DE ANTIOQUIA
# 16                      ALCALDÍA MUNICIPAL DE MAGANGUE
# 41          CORPORACION AUTONOMA REGIONAL DE SANTANDER
# 147                             SENA REGIONAL AMAZONAS
# 61                                   EDUNA (COMPRADOR)
# 0                                            AEROCIVIL
# 135  PARQUES NACIONALES NATURALES DE COLOMBIA - DIR...
#
#                           Categoría MACRO     Valor Total  Número de contratos
# 117                            Transporte  15062041107804                 1838
# 2                              Transporte   1061660300530                  315
# 52     Ambiental y gestion del territorio    352638388501                    5
# 118  Urbanismo y desarrollo metropolitano    308149391398                    1
# 116    Ambiental y gestion del territorio    225362347705                   22
# 25                             Transporte    147226582104                    1
# 56              Productiva y de servicios     84301533072                    3
# 68   Urbanismo y desarrollo metropolitano     72572848896                    4
# 26                             Transporte     24139080805                    6
# 69   Urbanismo y desarrollo metropolitano     16752030035                    7
# 54              Productiva y de servicios     14832929676                    2
# 64   Urbanismo y desarrollo metropolitano     12282031483                   17
# 55     Ambiental y gestion del territorio     11186550372                    1
# 50                             Transporte     10965018268                   34
# 87   Urbanismo y desarrollo metropolitano      9710125195                    1
# 10              Productiva y de servicios      9061645586                    2
# 66              Productiva y de servicios      8476383468                    2
# 82                             Transporte      8466668602                    2
# 140                            Transporte      7971214476                    1
# 17              Productiva y de servicios      7864116504                    4
# 77                             Transporte      7503194961                    7
# 5               Productiva y de servicios      7238071757                    3
# 121  Urbanismo y desarrollo metropolitano      7087500000                   42
# 129                            Transporte      7069041457                    4
# 51   Urbanismo y desarrollo metropolitano      6622994481                   20
# 63                             Transporte      6008953100                    7
# 130  Urbanismo y desarrollo metropolitano      5809616377                    1
# 57   Urbanismo y desarrollo metropolitano      5528619750                    2
# 120  Urbanismo y desarrollo metropolitano      4540242032                    2
# 128             Productiva y de servicios      4274187260                    3
# 39              Productiva y de servicios      4091799463                    1
# 125    Ambiental y gestion del territorio      3748898383                    1
# 49              Productiva y de servicios      3038600000                    5
# 65              Productiva y de servicios      2834839405                    1
# 16     Ambiental y gestion del territorio      1713891880                    2
# 41     Ambiental y gestion del territorio      1071850118                    2
# 147    Ambiental y gestion del territorio       582872946                    8
# 61     Ambiental y gestion del territorio       366650284                    1
# 0      Ambiental y gestion del territorio       136237782                    2
# 135    Ambiental y gestion del territorio       134224738                    4

# %%
# Top 10 por MACRO + SUB
entidad_macro_sub_top = (
    entidad_macro_sub
    .groupby(
        ['MACRO', 'SUB'],
        group_keys=False
    )
    .head(10)
)

print("Top 10 Entidades Contratantes por MACRO y SUB Categoria:")
display(entidad_macro_sub_top)
# Out:
# Top 10 Entidades Contratantes por MACRO y SUB Categoria:
#                                         nombre_entidad  \
# 143                                             INVIAS
# 140                                             INVIAS
# 141                                             INVIAS
# 3                                            AEROCIVIL
# 144                                             INVIAS
# ..                                                 ...
# 4                                            AEROCIVIL
# 106                              ICBF REGIONAL CORDOBA
# 190  SENA REGIONAL CHOCO GRUPO DE APOYO ADMINISTRAT...
# 129            INSTITUTO COLOMBIANO AGROPECUARIO - ICA
# 204  SENA REGIONAL QUINDIO GRUPO DE APOYO ADMINISTR...
#
#                                   MACRO                    SUB  \
# 143                          Transporte                   Vias
# 140                          Transporte                 Puente
# 141                          Transporte                 Puerto
# 3                            Transporte             Aeropuerto
# 144                          Transporte        Vias terciarias
# ..                                  ...                    ...
# 4                            Transporte                 Puente
# 106  Ambiental y gestion del territorio  Reservas y ecoparques
# 190  Ambiental y gestion del territorio  Reservas y ecoparques
# 129                          Transporte             Aeropuerto
# 204           Productiva y de servicios                Turismo
#
#         valor_total  contratos
# 143  10713837601341       1449
# 140   1730269755544         42
# 141   1704327987961         35
# 3      859791150490        285
# 144    781786686692        299
# ..              ...        ...
# 4          48589798          2
# 106        45884587          1
# 190        22110000          1
# 129        18047699          1
# 204        17182797          1
#
# [111 rows x 5 columns]

# %%
# Top 20 objetos por entidad
entidad_objeto_top = (
    entidad_objeto
    .groupby('nombre_entidad', group_keys=False)
    .head(20)
)
print("Top 20 Objetos Contractuales por Entidad Contratante:")
display(entidad_objeto_top)
# Out:
# Top 20 Objetos Contractuales por Entidad Contratante:
#                                         nombre_entidad objeto_contractual  \
# 151                                             INVIAS       Mejoramiento
# 149                                             INVIAS       Construccion
# 150                                             INVIAS      Mantenimiento
# 4                                            AEROCIVIL       Mejoramiento
# 66   CORPORACIÓN AUTÓNOMA DEL RÍO GRANDE DE LA MAGD...      Mantenimiento
# ..                                                 ...                ...
# 188                            SENA REGIONAL ATLANTICO         Adecuacion
# 157  MINISTERIO DEL TRABAJO - DIRECCIÓN TERRITORIAL...      Mantenimiento
# 119  INSTITUCION EDUCATIVA DISTRITAL ANTONIO JOSE D...         Reparacion
# 51   CONTRALORIA GENERAL DE LA REPUBLICA-CGR-GERENC...         Reparacion
# 140  INSTITUTO COLOMBIANO AGROPECUARIO-SECCIONAL CA...      Mantenimiento
#
#        valor_total  contratos
# 151  9767447247022        420
# 149  3021184516987         95
# 150  2283721229757       1067
# 4     421117682221         23
# 66    334460546954          3
# ..             ...        ...
# 188        7957598          1
# 157        6945700          1
# 119        3500000          1
# 51         3220000          1
# 140        1350000          1
#
# [237 rows x 4 columns]

# %%
# Top 10 entidades por MACRO + objeto
macro_objeto_entidad_top = (
    macro_objeto_entidad
    .groupby(
        ['MACRO', 'objeto_contractual'],
        group_keys=False
    )
    .head(10)
)

print("Top 10 Entidades Contratantes por MACRO Categoria y Objeto Contractual:")
display(macro_objeto_entidad_top)
# Out:
# Top 10 Entidades Contratantes por MACRO Categoria y Objeto Contractual:
#                                     MACRO objeto_contractual  \
# 175                            Transporte       Mejoramiento
# 131                            Transporte       Construccion
# 158                            Transporte      Mantenimiento
# 161                            Transporte       Mejoramiento
# 14     Ambiental y gestion del territorio      Mantenimiento
# ..                                    ...                ...
# 18     Ambiental y gestion del territorio      Mantenimiento
# 275  Urbanismo y desarrollo metropolitano              Otros
# 24     Ambiental y gestion del territorio              Otros
# 281  Urbanismo y desarrollo metropolitano         Reparacion
# 192                            Transporte         Reparacion
#
#                                         nombre_entidad    valor_total  \
# 175                                             INVIAS  9457847855624
# 131                                             INVIAS  3013821046772
# 158                                             INVIAS  2124647393299
# 161                                          AEROCIVIL   421056808486
# 14   CORPORACIÓN AUTÓNOMA DEL RÍO GRANDE DE LA MAGD...   334460546954
# ..                                                 ...            ...
# 18   SENA REGIONAL CHOCO GRUPO DE APOYO ADMINISTRAT...       22110000
# 275             INSTITUCION EDUCATIVA JOSE MARIA VILLA       11237928
# 24   SENA REGIONAL GUAINÍA GRUPO DE APOYO ADMINISTR...       10659700
# 281  INSTITUCION EDUCATIVA DISTRITAL ANTONIO JOSE D...        3500000
# 192  CONTRALORIA GENERAL DE LA REPUBLICA-CGR-GERENC...        3220000
#
#      contratos
# 175        417
# 131         93
# 158       1052
# 161         22
# 14           3
# ..         ...
# 18           1
# 275          1
# 24           1
# 281          1
# 192          1
#
# [186 rows x 5 columns]

# %% [markdown]
# ________________

# %%
ruta_salida = "CONTRATACION.xlsx"

with pd.ExcelWriter(
    os.path.join(DATAPATH, ruta_salida),
    engine="openpyxl", 
) as writer:
    entidades.to_excel(writer, sheet_name="Top_Entidades", index=False)
    entidad_macro_top.to_excel(writer, sheet_name="Entidad_x_MACRO", index=False)
    entidad_macro_sub_top.to_excel(writer, sheet_name="Entidad_x_MACRO_x_SUB", index=False)
    entidad_objeto_top.to_excel(writer, sheet_name="Entidad_x_Objeto", index=False)
    macro_objeto_entidad_top.to_excel(writer, sheet_name="MACRO_x_Objeto_x_Entidad", index=False)
